# %%
import matplotlib.pyplot as plt

from data_loading import AnimalKeypointsDataset

# %%
data = AnimalKeypointsDataset(json_file_path='../dataset/keypoints_annotations.json',
                              image_dir='../dataset/labeled/')

# %%
def show_landmarks(image, keypoints):
    """Show image with landmarks"""
    plt.imshow(image)
    plt.scatter(keypoints[:, 0] * image.width, keypoints[:, 1] * image.height, s=50, marker='.', c='r')

# %%
fig = plt.figure(figsize=(20, 20))

for i in range(len(data)):
    sample = data[i]

    print(i, '{}x{}'.format(sample['image'].width, sample['image'].height),
          sample['keypoints'].shape)

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    show_landmarks(**sample)

    if i == 3:
        plt.show()
        break
# Out:
# 0 480x281 (16, 3)
# 1 480x318 (16, 3)
# 2 480x320 (16, 3)
# 3 400x320 (16, 3)
